# %%
from IPython.display import Image
Image('C:/Users/Microsoft/Downloads/Capture.jpg')

# %% [markdown]
# In this Exgenous variable,The factor which are count as external factor./
# Like prouction of the farmer depends of waterfall.
# In this way again the we factor like humdity,land etc factor those factor we will consider as Exogenouse factor.
